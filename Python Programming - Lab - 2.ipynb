# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2101CS405</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# # if..else..

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
x = int(input("Enter a number:"))
if x > 0:
    print(x,"is positive")
elif x < 0:
    print(x,"is negative")
else:
    print("Number is Zero")
# Out:
# Enter a number:10
# 10 is positive

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even

# %%
y = int(input("Enter a number:"))
if y%2==0:
    print(y,"is Even")
else :
    print(y,"is Odd")
# Out:
# Enter a number:4
# 4 is Even

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
v = int(input("Enter 1st number:"))
w = int(input("Enter 2nd number:"))
if v > w :
    print(v, "is Largest")
else :
    print(w, "is Largest")
# Out:
# Enter 1st number:10
# Enter 2nd number:20
# 20 is Largest

# %%
m = int(input("Enter 1st number:"))
n = int(input("Enter 2nd number:"))
max = m if m>n else n
print(max,"is largest")
# Out:
# Enter 1st number:10
# Enter 2nd number:20
# 20 is largest

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
e = int(input("Enter 1st number:"))
f = int(input("Enter 2nd number:"))
g = int(input("Enter 3rd number:"))
if e>f and e>g:
    print(e, "is largest")
elif f>g:
    print(f, "is largest")
else:
    print(g, "is largest")
# Out:
# Enter 1st number:10
# Enter 2nd number:20
# Enter 3rd number:30
# 30 is largest

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("Enter year:"))
if year%400==0 or year%100!=0 and year%4==0:
    print(year, "is leap year")
else:
    print(year, "is not leap year")
# Out:
# Enter year:1990
# 1990 is not leap year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user

# %%
day_no = int(input("Enter day number:"))
if day_no==0:
    print("Sunday")
elif day_no==1:
    print("Monday")
elif day_no==2:
    print("Tuesday")
elif day_no==3:
    print("Wednesday")
elif day_no==4:
    print("Thursday")
elif day_no==5:
    print("Friday")
elif day_no==6:
    print("Saturday")
else:
    print("Wrong input")
# Out:
# Enter day number:1
# Monday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
no1 = int(input("Enter no1:"))
no2 = int(input("Enter no2:"))
print("Enter + for Addition")
print("Enter - for Subtraction")
print("Enter * for Multiplication")
print("Enter / for Division")
char = input("Enter Operation: ")
if char=='+':
    print("Ans is:",no1+no2)
elif char=='-':
    print("Ans is:",no1-no2)
elif char=='*':
    print("Ans is:",no1*no2)
elif char=='/':
    print("Ans is:",no1/no2)
else:
    print("Invalid input")
# Out:
# Enter no1:2
# Enter no2:3
# Enter + for Addition
# Enter - for Subtraction
# Enter * for Multiplication
# Enter / for Division
# Enter Operation: *
# Ans is: 6

# %% [markdown]
# ### 08) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# a. First 1 to 50 units – Rs. 2.60/unit</br>
# b. Next 50 to 100 units – Rs. 3.25/unit</br>
# c. Next 100 to 200 units – Rs. 5.26/unit</br>
# d. above 200 units – Rs. 8.45/unit

# %%
unit=int(input("Enter units: "))
if unit>1 and unit <=50:
    print("Electricity Bill:", unit*2.60)
elif unit>50 and unit <=100:
    print("Electricity Bill:",(50*2.60)+ (unit-50)*3.25)
elif unit>100 and unit <=200:
    print("Electricity Bill:",(50*2.60)+(100*3.25)+(unit-150)*5.26)
elif unit>200:
    print("Electricity Bill:",(50*2.60)+(50*3.25)+(100*5.26)+(unit-200)*8.45)
# Out:
# Enter units: 175
# Electricity Bill: 586.5

# %% [markdown]
# ### 01) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# Fail below 35 </br>
# Pass Class between 35 to 45 </br>
# Second Class</br>
# between 45 to 60</br>
# First Class between 60 to 70</br>
# Distinction if more than 70

# %%
sub1=int(input("Enter mark of sub1:"))
sub2=int(input("Enter mark of sub2:"))
sub3=int(input("Enter mark of sub3:"))
sub4=int(input("Enter mark of sub4:"))
sub5=int(input("Enter mark of sub5:"))
total=sub1+sub2+sub3+sub4+sub5
per=total/5
if per<35:
    print("Fail")
elif per>=35 and per<45:
    print("Pass Class")
elif per>=45 and per<60:
    print("Second Class")
elif per>=60 and per<70:
    print("First Class")
else:
    print("Distinction")
# Out:
# Enter mark of sub1:50
# Enter mark of sub2:50
# Enter mark of sub3:50
# Enter mark of sub4:50
# Enter mark of sub5:50
# Second Class

# %% [markdown]
# ### 02) WAP to find out the Maximum and Minimum number from given 4 numbers.

# %%
o=int(input("Enter 1st number:"))
p=int(input("Enter 2nd number:"))
q=int(input("Enter 3rd number:"))
r=int(input("Enter 4th number:"))

if(o>p and o>q and o>r):
    print(o, "is Maximum")

elif(p>q and p>r):
    print(p, "is Maximum")

elif(q>r):
    print(q, "is Maximum")

else:
    print(r, "is Maximum")
# Out:
# Enter 1st number:2
# Enter 2nd number:4
# Enter 3rd number:3
# Enter 4th number:1
# 4 is Maximum

# %%
o=int(input("Enter 1st number:"))
p=int(input("Enter 2nd number:"))
q=int(input("Enter 3rd number:"))
r=int(input("Enter 4th number:"))

if(o<p and o<q and o<r):
    print(o, "is Minimum")

elif(p<q and p<r):
    print(p, "is Minimum")

elif(q<r):
    print(q, "is Minimum")

else:
    print(r, "is Minimum")
# Out:
# Enter 1st number:6
# Enter 2nd number:3
# Enter 3rd number:2
# Enter 4th number:1
# 1 is Minimum

# %% [markdown]
# ### 03) WAP to input an integer number and check the last digit of number is even or odd.

# %%
number=int(input("Enter a number:"))
num=number%10
if num%2==0:
    print("Last digit of", number, "is even")
else:
    print("Last digit of", number, "is Odd")
# Out:
# Enter a number:125
# Last digit of 125 is Odd

# %% [markdown]
# ### 04) WAP to determine the roots of the equation ax2+bx+c=0.

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
c=int(input("Enter a number:"))
D=((b**2)-(4*a*c))**0.5
root1=((-b+D)/(2*a))
root2=((-b-D)/(2*a))
print("Root1:", root1)
print("Root2:", root2)
# Out:
# Enter a number:1
# Enter a number:0
# Enter a number:-1
# Root1: 1.0
# Root2: -1.0
