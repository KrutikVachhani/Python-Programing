# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2101CS405</b></center>
# <center><b><h1>Lab - 1</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World”

# %%
print('Hello World');
# Out:
# Hello World

# %% [markdown]
# ### 02) WAP to print your address i) using single print ii) using multiple print

# %%
print('''Shradhdha Park 4,
Street 1, Near LalPark D-Mart,
Haridhava Road-Rajkot''');
# Out:
# Shradhdha Park 4,
# Street 1, Near LalPark D-Mart,
# Haridhava Road-Rajkot

# %%
print('Shradhdha Park 4,')
print('Street 1, Near LalPark D-Mart,')
print('Haridhava Road-Rajkot');
# Out:
# Shradhdha Park 4,
# Street 1, Near LalPark D-Mart,
# Haridhava Road-Rajkot

# %% [markdown]
# ### 03) WAP to print addition of 2 numbers (without input function)

# %%
a=10;
b=20;
print('Sum =',a+b)
# Out:
# Sum = 30

# %% [markdown]
# ### 04) WAP to calculate and print average of 2 numbers (without input function)

# %%
a = 10
b = 20
avg=(a+b)/2
print('Average =',avg)
# Out:
# Average = 15.0

# %% [markdown]
# ### 05) WAP to add two number entered by user.

# %%
a = int(input('Enter number a:'))
b = int(input('Enter number b:'))
print('Sum =',a+b)
# Out:
# Enter number a:10
# Enter number b:20
# Sum = 30

# %% [markdown]
# ### 06) WAP to calculate simple interest.

# %%
p = int(input('Enter number p:'))
r = float(input('Enter number r:'))
n = int(input('Enter number n:'))
Interest=(p*r*n)/100
print("Interest =",Interest)
# Out:
# Enter number p:100000
# Enter number r:1.5
# Enter number n:1
# Interest = 1500.0

# %% [markdown]
# ### 07) WAP Calculate Area and Circumfrence of Circle

# %%
radius=float(input("Enter radius:"))
area=3.14*radius*radius
Circumference = 2*3.14*radius
print("Area =", area)
print("Circumference =", Circumference)
# Out:
# Enter radius:4
# Area = 50.24
# Circumference = 25.12

# %% [markdown]
# ### 08) WAP to print Multiplication table of given number without using loops.

# %%
n=int(input("Enter any number: "))

print(n, "* 1 = ",n*1)
print(n, "* 2 = ",n*2)
print(n, "* 3 = ",n*3)
print(n, "* 4 = ",n*4)
print(n, "* 5 = ",n*5)
print(n, "* 6 = ",n*6)
print(n, "* 7 = ",n*7)
print(n, "* 8 = ",n*8)
print(n, "* 9 = ",n*9)
print(n, "* 10 = ",n*10)
# Out:
# Enter any number: 5
# 5 * 1 =  5
# 5 * 2 =  10
# 5 * 3 =  15
# 5 * 4 =  20
# 5 * 5 =  25
# 5 * 6 =  30
# 5 * 7 =  35
# 5 * 8 =  40
# 5 * 9 =  45
# 5 * 10 =  50

# %% [markdown]
# ### 09) WAP to calculate Area of Triangle (hint: a = h * b * 0.5)

# %%
height=int(input("Enter value of height: "))
base=int(input("Enter value of base: "))
Tarea=(height*base)/2
print("Area =", Tarea)
# Out:
# Enter value of height: 10
# Enter value of base: 30
# Area = 150.0

# %% [markdown]
# ### 10) WAP to convert degree to Fahrenheit and vice versa.

# %%
C=int(input("Enter Temp. in Celcius: "))

fahrenheit=(1.8*C)+32

print("Feranhit =",fahrenheit)
# Out:
# Enter Temp. in Celcius: 40
# Feranhit = 104.0

# %%
F=int(input("Enter Temp. in Feranhit: "))

Celcius=(F-32)/1.8

print("Celcius =",Celcius)
# Out:
# Enter Temp. in Feranhit: 104
# Celcius = 40.0

# %% [markdown]
# ### 11) WAP to calculate total marks and Percentage.

# %%
sub1=int(input("Enter mark of sub1:"))
sub2=int(input("Enter mark of sub2:"))
sub3=int(input("Enter mark of sub3:"))
sub4=int(input("Enter mark of sub4:"))
sub5=int(input("Enter mark of sub5:"))
Total=sub1+sub2+sub3+sub4+sub5
Percentage=Total/5
print("Percentage = ",Percentage,"%")
# Out:
# Enter mark of sub1:20
# Enter mark of sub2:50
# Enter mark of sub3:60
# Enter mark of sub4:20
# Enter mark of sub5:30
# Percentage = 36.0 %

# %% [markdown]
# ### 12) Compute distance between two points taking input from the user (Pythagorean Theorem).

# %%
x1=int(input("Enter x1: "))
x2=int(input("Enter x2: "))
y1=int(input("Enter y1: "))
y2=int(input("Enter y2: "))

distance=(((y2-y1)**2)+((x2-x1)**2))**0.5

print("Distance =", distance)
# Out:
# Enter x1: 3
# Enter x2: 6
# Enter y1: 2
# Enter y2: 4
# Distance = 3.605551275463989

# %% [markdown]
# ### 13) WAP to convert seconds into hours, minutes & seconds and print in HH:MM:SS
# [e.g. 10000 seconds mean 2:46:40 (2 Hours, 46 Minutes, 40Seconds)]

# %%
Second=int(input('Enter Seconds: '))
Second=Second % (24 * 3600);
Hour=Second // 3600
Second %= 3600
Minute=Second // 60
Second %= 60
print("Time:",Hour,":",Minute,":",Second)
# Out:
# Enter Seconds: 10000
# Time: 2 : 46 : 40

# %% [markdown]
# ### 14) WAP to enter distance into kilometer and convert it into meter, feet,inches, and centimeter

# %%
Km=int(input("Enter Kilometer: "))

meter=Km*1000;
print("Meter =",meter)

Centimeter=meter*100
print("Centimeter =",Centimeter)

Feet=Centimeter*0.0328
print("Feet =",Feet)

Inch=Feet*12
print("Inch =",Inch)
# Out:
# Enter Kilometer: 10
# Meter = 10000
# Centimeter = 1000000
# Feet = 32800.0
# Inch = 393600.0
